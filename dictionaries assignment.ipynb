# %%
mobile = {
    'Apple': {
        '13': [38000, 45000, 52000],
        '14': [56000, 60000, 70000],
        '15': [67000, 72000, 82000]
    },

    'Samsung': {
        'S22': [67000, 89000],
        'S23': [89000, 95000],
        'S24': [90000, 123000]
    },

    'OPPO': {
        'Reno': [23000, 25000],
        'X': [34000, 45000]
    },

    'One Plus': {
        '8': [23000, 34000],
        '9': [34000, 45000],
        '10': [45000, 52000]
    },

    'Google': {
        '8': [89000, 90000, 100000],
        '9': [123000, 145000, 163000]
    }
}
print(mobile)
# Out:
# {'Apple': {'13': [38000, 45000, 52000], '14': [56000, 60000, 70000], '15': [67000, 72000, 82000]}, 'Samsung': {'S22': [67000, 89000], 'S23': [89000, 95000], 'S24': [90000, 123000]}, 'OPPO': {'Reno': [23000, 25000], 'X': [34000, 45000]}, 'One Plus': {'8': [23000, 34000], '9': [34000, 45000], '10': [45000, 52000]}, 'Google': {'8': [89000, 90000, 100000], '9': [123000, 145000, 163000]}}

# %%
mobile='Samsung': {
        'S22': [67000, 89000],
        'S23': [89000, 95000],
        'S24': [90000, 123000]
}

# %% [markdown]
# Q1. What is the total number and names of the models in the brand Samsung? 'Samsung': { 'S22': [67000, 89000], 'S23': [89000, 95000], 'S24': [90000, 123000] },

# %%
a=list(mobile["Samsung"].keys())
print(a)
print(len(a))
# Out:
# ['S22', 'S23', 'S24']
# 3

# %% [markdown]
# Q2. If you purchase 2 Samsung S24 base models and 3 Apple 14 highend mobiles, what will be the total price?

# %%
phone_1=(mobile["Samsung"]["S24"][0])
phone_2=(mobile["Apple"]["14"][2])

result=(phone_1*2+phone_2*3)
print(result)
# Out:
# 390000

# %% [markdown]
# Q3. If you purchase 20 Samsung S22 base models and 3 Google 9 highend mobiles, what will be the total price?

# %%
cell_1=(mobile["Samsung"]["S22"][0])
cell_2=(mobile["Google"]["9"][2])
total=(cell_1*20+cell_2*3)
print(total)
# Out:
# 1829000

# %% [markdown]
# Q4. How many models are there in the Apple Brand?

# %%
models=(mobile["Apple"].keys())
print(len(models))
# Out:
# 3

# %% [markdown]
# Q5. What are all the models available in Google?

# %%
mod=(mobile["Google"].keys())
print("Google has these models",set(mod))
# Out:
# Google has these models {'9', '8'}

# %% [markdown]
# Q6. How many price variants are there in Apple mobiles?

# %%
a=(mobile["Apple"]["13"])
a1=(mobile["Apple"]["14"])
a2=(mobile["Apple"]["15"])
b=(a)+(a1)+(a2)
c=(len(b))
print(c)
# Out:
# 9
